# %%
# esc a = add above , esc b = below

# %%
import requests
import pandas as pd
import json
from dateutil import parser

# %%
API_KEY = '5d207e81a642063c379f9cda976ba38c-0707387eafe41dfc10e61a1848749d1d'
ACCOUNT_ID = '101-004-29785198-001'
OANDA_URL = 'https://api-fxpractice.oanda.com/v3'

# %%
session = requests.Session()

# %%
session.headers.update({
    'Authorization': f'Bearer {API_KEY}',
    'Content-Type' : 'application/json'
}

)

# %%
params = dict(
    count = 10,
    granularity = 'H1',
    price = 'MBA'
)

# %%
url = f"{OANDA_URL}/accounts/{ACCOUNT_ID}/instruments"

# %%
response = session.get(url,params=None,data=None,headers=None)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['instruments', 'lastTransactionID'])

# %%
instruments_list = data['instruments']

# %%
instruments_list
# Out:
# [{'name': 'TRY_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'TRY/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'minimumTradeSize': '1',
#   'maximumTrailingStopDistance': '100.000',
#   'minimumTrailingStopDistance': '0.050',
#   'maximumPositionSize': '0',
#   'maximumOrderUnits': '100000000',
#   'marginRate': '0.25',
#   'guaranteedStopLossOrderMode': 'DISABLED',
#   'tags': [{'type': 'BRAIN_ASSET_CLASS', 'name': 'FX'},
#    {'type': 'ASSET_CLASS', 'name': 'CURRENCY'}],
#   'financing': {'longRate': '0.2975',
#    'shortRate': '-0.4237',
#    'financingDaysOfWeek': [{'dayOfWeek': 'MONDAY', 'daysCharged': 1},
#     {'dayOfWeek': 'TUESDAY', 'daysCharged': 1},
#     {'dayOfWeek': 'WEDNESDAY', 'daysCharged': 1},
#     {'dayOfWeek': 'THURSDAY', 'daysCharged': 1},
#     {'dayOfWeek': 'FRIDAY', 'daysCharged': 1},
#     {'dayOfWeek': 'SATURDAY', 'daysCharged': 0},
#     {'dayOfWeek': 'SUNDAY', 'daysCharged': 0}]}},
#  {'name': 'HKD_JPY',
# ...

# %%
key_i = ['name', 'type', 'displayName', 'pipLocation', 'displayPrecision', 'tradeUnitsPrecision','marginRate']

# %%
instruments_dict = {}
for i in instruments_list:
    key = i['name']
    instruments_dict[key] = {k:i[k] for k in key_i}

# %%
# # the complete for loop that is one line in the above row
# for k in key_i:
#     retrieved_data = instrument[k]
#     instruments_dict[key] = retrieved_data

# %%
instruments_dict.keys()
# Out:
# dict_keys(['TRY_JPY', 'HKD_JPY', 'US2000_USD', 'USD_PLN', 'GBP_AUD', 'XAU_GBP', 'NZD_USD', 'EUR_ZAR', 'AUD_JPY', 'XAG_EUR', 'XCU_USD', 'HK33_HKD', 'USB02Y_USD', 'USD_NOK', 'EU50_EUR', 'USB10Y_USD', 'XAU_XAG', 'SPX500_USD', 'XAU_SGD', 'BCO_USD', 'CAD_CHF', 'GBP_SGD', 'USD_SEK', 'NZD_SGD', 'ZAR_JPY', 'XAG_JPY', 'SGD_JPY', 'GBP_ZAR', 'USD_JPY', 'EUR_TRY', 'EUR_JPY', 'AUD_SGD', 'XAG_NZD', 'WTICO_USD', 'XAG_AUD', 'EUR_NZD', 'GBP_HKD', 'CHF_JPY', 'EUR_HKD', 'XAU_HKD', 'XAU_JPY', 'USD_THB', 'GBP_CHF', 'AUD_CHF', 'NZD_CHF', 'ESPIX_EUR', 'AUD_HKD', 'XAG_HKD', 'USD_CHF', 'XAG_CHF', 'CAD_HKD', 'CH20_CHF', 'USD_HKD', 'USB30Y_USD', 'AUD_NZD', 'XAG_SGD', 'AU200_AUD', 'CHF_ZAR', 'EUR_CHF', 'NL25_EUR', 'FR40_EUR', 'JP225_USD', 'SG30_SGD', 'USD_DKK', 'XAU_AUD', 'CAD_SGD', 'CHINAH_HKD', 'SOYBN_USD', 'EUR_DKK', 'CORN_USD', 'XPT_USD', 'XAU_EUR', 'DE30_EUR', 'USD_ZAR', 'CAD_JPY', 'XAG_CAD', 'NAS100_USD', 'USD_HUF', 'EUR_CAD', 'NATGAS_USD', 'EUR_USD', 'XPD_USD', 'EUR_HUF', 'CHF_HKD', 'XAU_CAD', 'DE10YB_EU
# ...

# %%
with open('../data/instruments.json','w') as f:
    f.write(json.dumps(instruments_dict,indent=2))

# %%
def fetch_candles(pair_name,count=10,granularity='H1'):
    url = f"{OANDA_URL}/instruments/{pair_name}/candles"
    params = dict(
        count = count,
        granularity = granularity,
        price = 'MBA')
    response = session.get(url,params=params,data=None,headers=None)
    data = response.json()

    if response.status_code==200:
        
        if 'candles' not in data:
            data =[]
        else:
            data = data['candles']

    return response.status_code , data

# %%
status , data = fetch_candles('EUR_USD',count=20)

# %%
data
# Out:
# [{'complete': True,
#   'volume': 4080,
#   'time': '2025-07-31T20:00:00.000000000Z',
#   'bid': {'o': '1.14117', 'h': '1.14175', 'l': '1.14089', 'c': '1.14140'},
#   'mid': {'o': '1.14124', 'h': '1.14184', 'l': '1.14096', 'c': '1.14148'},
#   'ask': {'o': '1.14132', 'h': '1.14192', 'l': '1.14103', 'c': '1.14157'}},
#  {'complete': True,
#   'volume': 329,
#   'time': '2025-07-31T21:00:00.000000000Z',
#   'bid': {'o': '1.14153', 'h': '1.14182', 'l': '1.14148', 'c': '1.14162'},
#   'mid': {'o': '1.14172', 'h': '1.14195', 'l': '1.14170', 'c': '1.14172'},
#   'ask': {'o': '1.14191', 'h': '1.14208', 'l': '1.14180', 'c': '1.14182'}},
#  {'complete': True,
#   'volume': 1503,
#   'time': '2025-07-31T22:00:00.000000000Z',
#   'bid': {'o': '1.14160', 'h': '1.14221', 'l': '1.14144', 'c': '1.14172'},
#   'mid': {'o': '1.14170', 'h': '1.14229', 'l': '1.14152', 'c': '1.14180'},
#   'ask': {'o': '1.14180', 'h': '1.14237', 'l': '1.14161', 'c': '1.14188'}},
#  {'complete': True,
# ...

# %%
prices = ['mid','bid','ask']
ohlc = ['o','h','l','c']

# %%
def get_candles_df(data):
    if len(data)==0:
        return pd.DataFrame()
    
    final_data=[]
    prices = ['mid','bid','ask']
    ohlc = ['o','h','l','c']

    for candle in data:
        if candle['complete'] == False:
            continue
        new_dict = {}
        new_dict['time'] = parser.parse(candle['time'])
        new_dict['volume'] = candle['volume']
        final_data.append(new_dict)
        for p in prices:
            for o in ohlc:
                new_dict[f'{p}_{o}'] = float(candle[p][o])

    df = pd.DataFrame.from_dict(final_data)
    return df

# %%
status , data = fetch_candles('EUR_USD',count=10,granularity='H4')
df = get_candles_df(data=data)

# %%
def create_data_file(pair_name,count=10,granularity='H1'):
    code,data = fetch_candles(pair_name,count,granularity)
    if code != 200:
        print('Failed', pair_name,data)
        return
    if len(data)==0:
        print('No candles',pair_name)
        return
    candles_df = get_candles_df(data)
    candles_df.to_pickle(f'../data/{pair_name}_{granularity}.pkl')
    print(f'{pair_name} {granularity} {candles_df.shape[0]} candles | {candles_df.time.min()} {candles_df.time.max()}')

# %%
create_data_file(pair_name='EUR_USD',count=10,granularity='H4')
# Out:
# EUR_USD H4 9 candles | 2025-07-31 01:00:00+00:00 2025-08-01 09:00:00+00:00

# %%
our_curr = ['EUR','USD','GBP','JPY','CHF','NZD','CAD','AUD']

# %%
for p1 in our_curr:
    for p2 in our_curr:
        pr = f'{p1}_{p2}'
        if pr in instruments_dict:
            for g in ['H1','H4']:
                
                create_data_file(pair_name=pr,count=4001,granularity=g)
# Out:
# EUR_USD H1 4000 candles | 2024-12-10 00:00:00+00:00 2025-08-01 14:00:00+00:00
# EUR_USD H4 4000 candles | 2023-01-05 22:00:00+00:00 2025-08-01 09:00:00+00:00
# EUR_GBP H1 4000 candles | 2024-12-10 00:00:00+00:00 2025-08-01 14:00:00+00:00
# EUR_GBP H4 4000 candles | 2023-01-05 22:00:00+00:00 2025-08-01 09:00:00+00:00
# EUR_JPY H1 4000 candles | 2024-12-10 00:00:00+00:00 2025-08-01 14:00:00+00:00
# EUR_JPY H4 4000 candles | 2023-01-05 22:00:00+00:00 2025-08-01 09:00:00+00:00
# EUR_CHF H1 4000 candles | 2024-12-10 00:00:00+00:00 2025-08-01 14:00:00+00:00
# EUR_CHF H4 4000 candles | 2023-01-05 22:00:00+00:00 2025-08-01 09:00:00+00:00
# EUR_NZD H1 4000 candles | 2024-12-09 23:00:00+00:00 2025-08-01 14:00:00+00:00
# EUR_NZD H4 4000 candles | 2023-01-06 06:00:00+00:00 2025-08-01 09:00:00+00:00
# EUR_CAD H1 4000 candles | 2024-12-10 00:00:00+00:00 2025-08-01 14:00:00+00:00
# EUR_CAD H4 4000 candles | 2023-01-05 22:00:00+00:00 2025-08-01 09:00:00+00:00
# ...
