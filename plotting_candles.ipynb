# %%
import pandas as pd
import plotly.graph_objects as go
import datetime as dt

# %%
pair = 'EUR_USD'
granularity = 'H4'
df = pd.read_pickle(f'../data/{pair}_{granularity}.pkl')

# %%
df['sTime']=[dt.datetime.strftime(x,'s%y-%m-%d %H:%M') for x in df.time]

# %%
df_plot = df.iloc[:100]

# %%
fig = go.Figure()

fig.add_trace(go.Candlestick(
    x=df_plot.sTime,
    open = df_plot.mid_o,
    low = df_plot.mid_l,
    high = df_plot.mid_h,
    close = df_plot.mid_c,
    line=dict(width=1),opacity=1,
    increasing_fillcolor='#24A06B',
    decreasing_fillcolor="#C52020",
    increasing_line_color='#24A06B',
    decreasing_line_color="#D82323",

))

fig.update_yaxes(
    gridcolor='#1f292f'
)
fig.update_xaxes(
    gridcolor='#1f292f',
    rangeslider=dict(visible=False),
    nticks=5
)


fig.update_layout(
    width=900,
    height=400,
    margin=dict(l=10,r=10,b=10,t=10),
    paper_bgcolor='#2c303c',
    plot_bgcolor='#2c303c'
)


fig.show()
